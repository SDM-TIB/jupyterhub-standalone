# %% [markdown]
# # **Empowering Healthcare with Symbolic Learning and Knowledge Graph Embeddings**

# %% [markdown]
# ![Desing Pattern](https://github.com/SDM-TIB/HyAI/assets/25593410/42cf771d-b82d-4097-b0f7-0ceb3581b171)

# %% [markdown]
# ## **Pattern Detection, Analysis and Explanation over Lung Cancer Knowledge Graph**
#
# >> **Pattern Detection. Unsupervised learning**
# *   Learned embeddings of the entities in the Knowledge Graph
# *   Apply community detection Algorithms: SemEP, KMeans
# *   Compute the quality of the communities generated
# *   Generate Radar-plots

# %% [markdown]
# Git clone

# %%
# !git clone https://github.com/SDM-TIB/SymbolicLearning_KGE.git
# %cd SymbolicLearning_KGE/PatternDetection
# Out:
# Cloning into 'SymbolicLearning_KGE'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 630 (delta 65), reused 69 (delta 28), pack-reused 509 (from 1)
# Receiving objects: 100% (630/630), 32.68 MiB | 13.84 MiB/s, done.
# Resolving deltas: 100% (306/306), done.
# /home/jovyan/work/SymbolicLearning_KGE/PatternDetection

# %% [markdown]
# Install rdflib

# %%
# !pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-7.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from rdflib) (3.1.1)
# Downloading rdflib-7.1.4-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rdflib
# Successfully installed rdflib-7.1.4

# %%
import ComputeCommunities as SemCD
import EvaluationMetric
import StatisticKG

# %% [markdown]
# **Clean the build**

# %%
# !make clean
# Out:
#  **** Cleaning all in /home/jovyan/work/SymbolicLearning_KGE/PatternDetection  ****
# (cd src/ ; make clean)
# make[1]: Entering directory '/home/jovyan/work/SymbolicLearning_KGE/PatternDetection/src'
# rm -rf ../semEP-node *.o *.dSYM ../*.dSYM *~
# make[1]: Leaving directory '/home/jovyan/work/SymbolicLearning_KGE/PatternDetection/src'

# %% [markdown]
# **Build the project**

# %%
# !make
# Out:
#  **********************************
#  ****         Compiling        ****
#  **********************************
#
# (cd src/ ; make)
# make[1]: Entering directory '/home/jovyan/work/SymbolicLearning_KGE/PatternDetection/src'
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  util.c -o util.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  graph_adj.c -o graph_adj.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  hash_iset.c -o hash_iset.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  hash_map.c -o hash_map.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  input.c -o input.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  solver.c -o solver.o
# cc -c  -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes  main.c -o main.o
# cc -Wall -Wextra -O3 -ffast-math -std=gnu99 -march=native -mtune=native -Wshadow -Wpointer-arith -Wstrict-prototypes -Wmissing-prototypes -o ../semEP-node util.o graph_adj.o hash_iset.o hash_map.o input.o solver.o main.o -lm
# make[1]: Leaving directory '/home/jovyan/work/SymbolicLearning_KGE/PatternDetection/src'

# %% [markdown]
# **Statistics of Lung Cancer Knowledge Graph**

# %%
kg_name = 'TransformedKG'
StatisticKG.plot_statistics(kg_name)

# %% [markdown]
# ## Run the semEP-node

# %% [markdown]
# **Parameter input**

# %%
model_list = ['TransH', 'RotatE']
threshold = [35, 36, 37, 64, 65]
kg_name = 'TransformedKG'
target_predicate = 'hasRelapse_Progression'

# %%
SemCD.run(kg_name=kg_name, target_predicate=target_predicate,
          model_list=model_list, threshold=threshold)
# Out:
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.557
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0320 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 281
# Start coloring
# Average density of the partitions: 0.7540
# Number of partitions: 2
# Cluster directory: ClinicalRecord-0.5567-7h-57m-13s-Clusters
# Coloring solver time: 0.0113 secs
# Total time 0.291 secs
# Community Detection by SemEP and Kmeans, considering TransH model and threshold 35 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.562
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0354 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 352
# Start coloring
# Average density of the partitions: 0.7533
# Number of partitions: 2
# Cluster directory: ClinicalRecord-0.5616-7h-57m-35s-Clusters
# Coloring solver time: 0.0116 secs
# Total time 0.316 secs
# Community Detection by SemEP and Kmeans, considering TransH model and threshold 36 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.567
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0410 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 589
# Start coloring
# Average density of the partitions: 0.7747
# Number of partitions: 3
# Cluster directory: ClinicalRecord-0.5665-7h-58m-0s-Clusters
# Coloring solver time: 0.0131 secs
# Total time 0.312 secs
# Community Detection by SemEP and Kmeans, considering TransH model and threshold 37 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.730
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 1.3081 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 159609
# Start coloring
# Average density of the partitions: 0.3112
# Number of partitions: 84
# Cluster directory: ClinicalRecord-0.7296-7h-58m-27s-Clusters
# Coloring solver time: 0.0221 secs
# Total time 1.580 secs
# Community Detection by SemEP and Kmeans, considering TransH model and threshold 64 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/TransH/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/TransH/matrix_ClinicalRecord.tsv
# Threshold: 0.737
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/TransH/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 1.3122 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 169443
# Start coloring
# Average density of the partitions: 0.2937
# Number of partitions: 91
# Cluster directory: ClinicalRecord-0.7369-7h-58m-56s-Clusters
# Coloring solver time: 0.0228 secs
# Total time 1.574 secs
# Community Detection by SemEP and Kmeans, considering TransH model and threshold 65 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.521
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0158 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5581
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5209-7h-59m-26s-Clusters
# Coloring solver time: 0.0095 secs
# Total time 0.269 secs
# Community Detection by SemEP and Kmeans, considering RotatE model and threshold 35 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.523
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0230 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5581
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5233-7h-59m-47s-Clusters
# Coloring solver time: 0.0157 secs
# Total time 0.315 secs
# Community Detection by SemEP and Kmeans, considering RotatE model and threshold 36 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.526
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0164 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 0
# Start coloring
# Average density of the partitions: 0.5581
# Number of partitions: 1
# Cluster directory: ClinicalRecord-0.5257-8h-0m-8s-Clusters
# Coloring solver time: 0.0092 secs
# Total time 0.272 secs
# Community Detection by SemEP and Kmeans, considering RotatE model and threshold 37 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.589
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0516 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 70
# Start coloring
# Average density of the partitions: 0.5829
# Number of partitions: 2
# Cluster directory: ClinicalRecord-0.5891-8h-0m-30s-Clusters
# Coloring solver time: 0.0161 secs
# Total time 0.323 secs
# Community Detection by SemEP and Kmeans, considering RotatE model and threshold 64 done.
#
# **********************************************
# Parameters:
# Nodes file name: clusteringMeasures/RotatE/ClinicalRecord.txt
# Matrix file name: clusteringMeasures/RotatE/matrix_ClinicalRecord.tsv
# Threshold: 0.592
# ************************************************
#
# **** GO semEP-Node! ****
# Proccessing the vertex file clusteringMeasures/RotatE/ClinicalRecord.txt ...
# Number of nodes of the input file: 1242
# Time to build the graph to coloring: 0.0567 secs
# Graph to coloring - Num. of Nodes: 1242; Num. of Edges: 108
# Start coloring
# Average density of the partitions: 0.5822
# Number of partitions: 2
# Cluster directory: ClinicalRecord-0.5916-8h-0m-52s-Clusters
# Coloring solver time: 0.0113 secs
# Total time 0.324 secs
# Community Detection by SemEP and Kmeans, considering RotatE model and threshold 65 done.

# %% [markdown]
# ## Quality of the generated communities

# %% [markdown]
# * Conductance (**InvC**): measures relatedness of entities in a community, and how different they are to entities outside the community.
# * Performance (**P**): sums up the number of intra-community relationships, plus the number of non-existent relationships between communities.
# * Total Cut (**InvTC**): sums up all similarities among entities in different communities.
# * Modularity (**M**): measures the strength of the division of a graph into communities by comparing the density of connections inside communities to density of connections between different communities.
# * Coverage (**Co**): compares the fraction of intra-community similarities between entities to the sum of all similarities between entities.

# %% [markdown]
# Moving to clusteringMeasures folder

# %%
# %cd clusteringMeasures

# %% [markdown]
# **Clean the build**

# %%
# !make clean

# %% [markdown]
# **Build the project**

# %%
# !make

# %% [markdown]
# **Compute Metrices**

# %%
import ComputeMetrices
ComputeMetrices.run(model_list, threshold)

# %% [markdown]
# **Generate Radar Plot**

# %%
# %cd ../
EvaluationMetric.GenerateRadarPlot(model_list, threshold)

# %% [markdown]
# # Analysis and Explanation over P4-LUCAT Knowledge Graph

# %% [markdown]
# >> **Pattern Analysis and Explanation**
# *   Visualize PCA Projection to 2D of the detected cummunities
# *   Selecting a target predicate to analyze
# *   Distribution of Relapse by Community

# %%
# %%capture
# %cd ../PatternAnalysisExplanation
# !pip install PyMuPDF
import PatternAnalysis
import pandas as pd

# %% [markdown]
# **Visualize PCA Projection to 2D of the detected cummunities**

# %%
PatternAnalysis.PCA_projection(kg_name, model_list[0], threshold[1])
PatternAnalysis.PCA_projection(kg_name, model_list[1], threshold[3])

# %% [markdown]
# **Targeting the clusters with the '*target_predicate*' selected**

# %%
target_cls = PatternAnalysis.target_cluster(kg_name, model_list[1], target_predicate, 'SemEP', threshold[3])
display(target_cls.head(), target_cls.shape)

# %% [markdown]
# **Compute the amount of patients for each the target value (column Relapse) and community**

# %%
df = target_cls[['Relapse', 'Community']]
q = df.groupby(['Relapse', 'Community']).size().reset_index(name='count_values')
df_reset = q.reset_index(drop=True)
df_reset

# %% [markdown]
# **Normalized Clinical Records**

# %%
# Group by 'Relapse' and sum 'count_values'
result = df_reset.groupby('Relapse')['count_values'].sum().reset_index()

a = df_reset.loc[df_reset.Relapse=='No relapse'].copy()
b = df_reset.loc[df_reset.Relapse=='Relapse'].copy()
c = df_reset.loc[df_reset.Relapse=='UnKnown'].copy()
a['count_values'] = a['count_values']/result[result['Relapse'] == 'No relapse']['count_values'].values[0]
b['count_values'] = b['count_values']/result[result['Relapse'] == 'Relapse']['count_values'].values[0]
c['count_values'] = c['count_values']/result[result['Relapse'] == 'UnKnown']['count_values'].values[0]

df_reset = pd.concat([a, b, c])
df_reset

# %% [markdown]
# ## **Visualization**

# %%
PatternAnalysis.catplot(df_reset, model_list[1])
